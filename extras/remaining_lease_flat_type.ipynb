# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
hdb = pd.read_csv('hdb.csv')

# %%
house = hdb.groupby(["town","year","flat_type","remaining_lease" ,"resale_price"]).size().reset_index(name='counts').sort_values("counts", ascending = False)

# %%
house = house.reset_index(drop = True)

# %%
room3 = house[(house.flat_type == "3 ROOM")]
room4 = house[(house.flat_type == "4 ROOM")]
room5 = house[(house.flat_type == "5 ROOM")]
test3 = house[(house.flat_type == "3 ROOM")]
test4 = house[(house.flat_type == "4 ROOM")]
test5 = house[(house.flat_type == "5 ROOM")]

# %%
def univariateLinearRegression(Xvar = None, yvar = None, df = None):
    '''
        Function to perform Linear Regression with Xvar and yvar in df.
        Prints the required plots within the function. Returns nothing.
    '''    
    # Extract Response and Predictors
    y = pd.DataFrame(df[yvar])
    X = pd.DataFrame(df[Xvar])

    # Split the Dataset into random Train and Test (80:20)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
    
    linreg = LinearRegression()         # create the linear regression object
    linreg.fit(X_train, y_train)        # train the linear regression model

    # Print the coefficients of the Regression Line
    print('Intercept \t: b = ', linreg.intercept_)
    print('Coefficients \t: a = ', linreg.coef_)
    
    # Formula for the Regression line
    regline_x = X_train
    regline_y = linreg.intercept_ + linreg.coef_ * X_train
    
    # Predict Response corresponding to Predictors
    y_train_pred = linreg.predict(X_train)
    y_test_pred = linreg.predict(X_test)
    
    # Plot the Predictions vs the True values
    f, axes = plt.subplots(1, 2, figsize=(24, 12))
    axes[0].scatter(X_train, y_train, color = "blue")
    axes[0].plot(regline_x, regline_y, 'r-', linewidth = 3)
    axes[0].set_title("Regression Line on Train Set")
    axes[1].scatter(X_test, y_test, color = "green")
    axes[1].scatter(X_test, y_test_pred, color = "red")
    axes[1].set_title("Model Prediction on Test Set")
    plt.show()

    # Check the Goodness of Fit (on Train Data)
    print("Goodness of Fit of Model \tTrain Dataset")
    print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
    print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
    print()

    # Check the Goodness of Fit (on Test Data)
    print("Prediction Accuracy of Model \tTest Dataset")
    print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
    print()

# %%
bedok = room3[(room3.town == 'BEDOK')]
jw = room3[(room3.town == 'JURONG WEST')]
tampines = room3[(room3.town == 'TAMPINES')]
woodlands = room3[(room3.town == 'WOODLANDS')]
yishun = room3[(room3.town == 'YISHUN')]
hougang = room3[(room3.town == 'HOUGANG')]
bukitmerah = room3[(room3.town == 'BUKIT MERAH')]
amk = room3[(room3.town == 'ANG MO KIO')]
toapayoh = room3[(room3.town == 'TOA PAYOH')]
kallang = room3[(room3.town == 'KALLANG/WHAMPOA')]
bukitbatok = room3[(room3.town == 'BUKIT BATOK')]
geylang = room3[(room3.town == 'GEYLANG')]
queenstown = room3[(room3.town == 'QUEENSTOWN')]
cck = room3[(room3.town == 'CHOA CHU KANG')]
je = room3[(room3.town == 'JURONG EAST')]
clem = room3[(room3.town == 'CLEMENTI')]
bukitpanjang = room3[(room3.town == 'BUKIT PANJANG')]
bishan = room3[(room3.town == 'BISHAN')]
serangoon = room3[(room3.town == 'SERANGOON')]
sengkang = room3[(room3.town == 'SENG KANG')]
pasirris = room3[(room3.town == 'PASIR RIS')]
marineparade = room3[(room3.town == 'MARINE PARADE')]
sembawang = room3[(room3.town == 'SEMBAWANG')]
punggol = room3[(room3.town == 'PUNGGOL')]
central = room3[(room3.town == 'CENTRAL AREA')]
bukittimah = room3[(room3.town == 'BUKIT TIMAH')]
lck = room3[(room3.town == 'LIM CHU KANG')]

# %%
f = plt.figure(figsize=(16, 8))
bedok = bedok.groupby("remaining_lease").median().reset_index()
jw = jw.groupby("remaining_lease").median().reset_index()
tampines = tampines.groupby("remaining_lease").median().reset_index()
woodlands = woodlands.groupby("remaining_lease").median().reset_index()
yishun = yishun.groupby("remaining_lease").median().reset_index()
hougang = hougang.groupby("remaining_lease").median().reset_index()
bukitmerah = bukitmerah.groupby("remaining_lease").median().reset_index()
amk = amk.groupby("remaining_lease").median().reset_index()
toapayoh = toapayoh.groupby("remaining_lease").median().reset_index()
kallang = kallang.groupby("remaining_lease").median().reset_index()
bukitbatok = bukitbatok.groupby("remaining_lease").median().reset_index()
geylang = geylang.groupby("remaining_lease").median().reset_index()
queenstown = queenstown.groupby("remaining_lease").median().reset_index()
cck = cck.groupby("remaining_lease").median().reset_index()
je = je.groupby("remaining_lease").median().reset_index()
clem = clem.groupby("remaining_lease").median().reset_index()
bukitpanjang = bukitpanjang.groupby("remaining_lease").median().reset_index()
bishan = bishan.groupby("remaining_lease").median().reset_index()
serangoon = serangoon.groupby("remaining_lease").median().reset_index()
sengkang = sengkang.groupby("remaining_lease").median().reset_index()
pasirris = pasirris.groupby("remaining_lease").median().reset_index()
marineparade = marineparade.groupby("remaining_lease").median().reset_index()
sembawang = sembawang.groupby("remaining_lease").median().reset_index()
punggol = punggol.groupby("remaining_lease").median().reset_index()
central = central.groupby("remaining_lease").median().reset_index()
bukittimah = bukittimah.groupby("remaining_lease").median().reset_index()
lck = lck.groupby("remaining_lease").median().reset_index()
sb.lineplot(x='remaining_lease', y='resale_price', data=bedok)
sb.lineplot(x='remaining_lease', y='resale_price', data=jw)
sb.lineplot(x='remaining_lease', y='resale_price', data=tampines)
sb.lineplot(x='remaining_lease', y='resale_price', data=woodlands)
sb.lineplot(x='remaining_lease', y='resale_price', data=yishun)
sb.lineplot(x='remaining_lease', y='resale_price', data=hougang)
sb.lineplot(x='remaining_lease', y='resale_price', data=bukitmerah)
sb.lineplot(x='remaining_lease', y='resale_price', data=amk)
sb.lineplot(x='remaining_lease', y='resale_price', data=toapayoh)
sb.lineplot(x='remaining_lease', y='resale_price', data=kallang)
sb.lineplot(x='remaining_lease', y='resale_price', data=bukitbatok)
sb.lineplot(x='remaining_lease', y='resale_price', data=geylang)
sb.lineplot(x='remaining_lease', y='resale_price', data=queenstown)
sb.lineplot(x='remaining_lease', y='resale_price', data=cck)
sb.lineplot(x='remaining_lease', y='resale_price', data=je)
sb.lineplot(x='remaining_lease', y='resale_price', data=clem)
sb.lineplot(x='remaining_lease', y='resale_price', data=bukitpanjang)
sb.lineplot(x='remaining_lease', y='resale_price', data=bishan)
sb.lineplot(x='remaining_lease', y='resale_price', data=serangoon)
sb.lineplot(x='remaining_lease', y='resale_price', data=sengkang)
sb.lineplot(x='remaining_lease', y='resale_price', data=pasirris)
sb.lineplot(x='remaining_lease', y='resale_price', data=marineparade)
sb.lineplot(x='remaining_lease', y='resale_price', data=sembawang)
sb.lineplot(x='remaining_lease', y='resale_price', data=punggol)
sb.lineplot(x='remaining_lease', y='resale_price', data=central)
sb.lineplot(x='remaining_lease', y='resale_price', data=bukittimah)
sb.lineplot(x='remaining_lease', y='resale_price', data=lck)
# Out:
# <AxesSubplot:xlabel='remaining_lease', ylabel='resale_price'>

# %%
bedok = room4[(room4.town == 'BEDOK')]
jw = room4[(room4.town == 'JURONG WEST')]
tampines = room4[(room4.town == 'TAMPINES')]
woodlands = room4[(room4.town == 'WOODLANDS')]
yishun = room4[(room4.town == 'YISHUN')]
hougang = room4[(room4.town == 'HOUGANG')]
bukitmerah = room4[(room4.town == 'BUKIT MERAH')]
amk = room4[(room4.town == 'ANG MO KIO')]
toapayoh = room4[(room4.town == 'TOA PAYOH')]
kallang = room4[(room4.town == 'KALLANG/WHAMPOA')]
bukitbatok = room4[(room4.town == 'BUKIT BATOK')]
geylang = room4[(room4.town == 'GEYLANG')]
queenstown = room4[(room4.town == 'QUEENSTOWN')]
cck = room4[(room4.town == 'CHOA CHU KANG')]
je = room4[(room4.town == 'JURONG EAST')]
clem = room4[(room4.town == 'CLEMENTI')]
bukitpanjang = room4[(room4.town == 'BUKIT PANJANG')]
bishan = room4[(room4.town == 'BISHAN')]
serangoon = room4[(room4.town == 'SERANGOON')]
sengkang = room4[(room4.town == 'SENG KANG')]
pasirris = room4[(room4.town == 'PASIR RIS')]
marineparade = room4[(room4.town == 'MARINE PARADE')]
sembawang = room4[(room4.town == 'SEMBAWANG')]
punggol = room4[(room4.town == 'PUNGGOL')]
central = room4[(room4.town == 'CENTRAL AREA')]
bukittimah = room4[(room4.town == 'BUKIT TIMAH')]
lck = room4[(room4.town == 'LIM CHU KANG')]

# %%
f = plt.figure(figsize=(16, 8))
bedok = bedok.groupby("remaining_lease").median().reset_index()
jw = jw.groupby("remaining_lease").median().reset_index()
tampines = tampines.groupby("remaining_lease").median().reset_index()
woodlands = woodlands.groupby("remaining_lease").median().reset_index()
yishun = yishun.groupby("remaining_lease").median().reset_index()
hougang = hougang.groupby("remaining_lease").median().reset_index()
bukitmerah = bukitmerah.groupby("remaining_lease").median().reset_index()
amk = amk.groupby("remaining_lease").median().reset_index()
toapayoh = toapayoh.groupby("remaining_lease").median().reset_index()
kallang = kallang.groupby("remaining_lease").median().reset_index()
bukitbatok = bukitbatok.groupby("remaining_lease").median().reset_index()
geylang = geylang.groupby("remaining_lease").median().reset_index()
queenstown = queenstown.groupby("remaining_lease").median().reset_index()
cck = cck.groupby("remaining_lease").median().reset_index()
je = je.groupby("remaining_lease").median().reset_index()
clem = clem.groupby("remaining_lease").median().reset_index()
bukitpanjang = bukitpanjang.groupby("remaining_lease").median().reset_index()
bishan = bishan.groupby("remaining_lease").median().reset_index()
serangoon = serangoon.groupby("remaining_lease").median().reset_index()
sengkang = sengkang.groupby("remaining_lease").median().reset_index()
pasirris = pasirris.groupby("remaining_lease").median().reset_index()
marineparade = marineparade.groupby("remaining_lease").median().reset_index()
sembawang = sembawang.groupby("remaining_lease").median().reset_index()
punggol = punggol.groupby("remaining_lease").median().reset_index()
central = central.groupby("remaining_lease").median().reset_index()
bukittimah = bukittimah.groupby("remaining_lease").median().reset_index()
lck = lck.groupby("remaining_lease").median().reset_index()
sb.lineplot(x='remaining_lease', y='resale_price', data=bedok)
sb.lineplot(x='remaining_lease', y='resale_price', data=jw)
sb.lineplot(x='remaining_lease', y='resale_price', data=tampines)
sb.lineplot(x='remaining_lease', y='resale_price', data=woodlands)
sb.lineplot(x='remaining_lease', y='resale_price', data=yishun)
sb.lineplot(x='remaining_lease', y='resale_price', data=hougang)
sb.lineplot(x='remaining_lease', y='resale_price', data=bukitmerah)
sb.lineplot(x='remaining_lease', y='resale_price', data=amk)
sb.lineplot(x='remaining_lease', y='resale_price', data=toapayoh)
sb.lineplot(x='remaining_lease', y='resale_price', data=kallang)
sb.lineplot(x='remaining_lease', y='resale_price', data=bukitbatok)
sb.lineplot(x='remaining_lease', y='resale_price', data=geylang)
sb.lineplot(x='remaining_lease', y='resale_price', data=queenstown)
sb.lineplot(x='remaining_lease', y='resale_price', data=cck)
sb.lineplot(x='remaining_lease', y='resale_price', data=je)
sb.lineplot(x='remaining_lease', y='resale_price', data=clem)
sb.lineplot(x='remaining_lease', y='resale_price', data=bukitpanjang)
sb.lineplot(x='remaining_lease', y='resale_price', data=bishan)
sb.lineplot(x='remaining_lease', y='resale_price', data=serangoon)
sb.lineplot(x='remaining_lease', y='resale_price', data=sengkang)
sb.lineplot(x='remaining_lease', y='resale_price', data=pasirris)
sb.lineplot(x='remaining_lease', y='resale_price', data=marineparade)
sb.lineplot(x='remaining_lease', y='resale_price', data=sembawang)
sb.lineplot(x='remaining_lease', y='resale_price', data=punggol)
sb.lineplot(x='remaining_lease', y='resale_price', data=central)
sb.lineplot(x='remaining_lease', y='resale_price', data=bukittimah)
sb.lineplot(x='remaining_lease', y='resale_price', data=lck)
# Out:
# <AxesSubplot:xlabel='remaining_lease', ylabel='resale_price'>

# %%
bedok = room5[(room5.town == 'BEDOK')]
jw = room5[(room5.town == 'JURONG WEST')]
tampines = room5[(room5.town == 'TAMPINES')]
woodlands = room5[(room5.town == 'WOODLANDS')]
yishun = room5[(room5.town == 'YISHUN')]
hougang = room5[(room5.town == 'HOUGANG')]
bukitmerah = room5[(room5.town == 'BUKIT MERAH')]
amk = room5[(room5.town == 'ANG MO KIO')]
toapayoh = room5[(room5.town == 'TOA PAYOH')]
kallang = room5[(room5.town == 'KALLANG/WHAMPOA')]
bukitbatok = room5[(room5.town == 'BUKIT BATOK')]
geylang = room5[(room5.town == 'GEYLANG')]
queenstown = room5[(room5.town == 'QUEENSTOWN')]
cck = room5[(room5.town == 'CHOA CHU KANG')]
je = room5[(room5.town == 'JURONG EAST')]
clem = room5[(room5.town == 'CLEMENTI')]
bukitpanjang = room5[(room5.town == 'BUKIT PANJANG')]
bishan = room5[(room5.town == 'BISHAN')]
serangoon = room5[(room5.town == 'SERANGOON')]
sengkang = room5[(room5.town == 'SENG KANG')]
pasirris = room5[(room5.town == 'PASIR RIS')]
marineparade = room5[(room5.town == 'MARINE PARADE')]
sembawang = room5[(room5.town == 'SEMBAWANG')]
punggol = room5[(room5.town == 'PUNGGOL')]
central = room5[(room5.town == 'CENTRAL AREA')]
bukittimah = room5[(room5.town == 'BUKIT TIMAH')]
lck = room5[(room5.town == 'LIM CHU KANG')]

# %%
f = plt.figure(figsize=(16, 8))
bedok = bedok.groupby("remaining_lease").median().reset_index()
jw = jw.groupby("remaining_lease").median().reset_index()
tampines = tampines.groupby("remaining_lease").median().reset_index()
woodlands = woodlands.groupby("remaining_lease").median().reset_index()
yishun = yishun.groupby("remaining_lease").median().reset_index()
hougang = hougang.groupby("remaining_lease").median().reset_index()
bukitmerah = bukitmerah.groupby("remaining_lease").median().reset_index()
amk = amk.groupby("remaining_lease").median().reset_index()
toapayoh = toapayoh.groupby("remaining_lease").median().reset_index()
kallang = kallang.groupby("remaining_lease").median().reset_index()
bukitbatok = bukitbatok.groupby("remaining_lease").median().reset_index()
geylang = geylang.groupby("remaining_lease").median().reset_index()
queenstown = queenstown.groupby("remaining_lease").median().reset_index()
cck = cck.groupby("remaining_lease").median().reset_index()
je = je.groupby("remaining_lease").median().reset_index()
clem = clem.groupby("remaining_lease").median().reset_index()
bukitpanjang = bukitpanjang.groupby("remaining_lease").median().reset_index()
bishan = bishan.groupby("remaining_lease").median().reset_index()
serangoon = serangoon.groupby("remaining_lease").median().reset_index()
sengkang = sengkang.groupby("remaining_lease").median().reset_index()
pasirris = pasirris.groupby("remaining_lease").median().reset_index()
marineparade = marineparade.groupby("remaining_lease").median().reset_index()
sembawang = sembawang.groupby("remaining_lease").median().reset_index()
punggol = punggol.groupby("remaining_lease").median().reset_index()
central = central.groupby("remaining_lease").median().reset_index()
bukittimah = bukittimah.groupby("remaining_lease").median().reset_index()
lck = lck.groupby("remaining_lease").median().reset_index()
sb.lineplot(x='remaining_lease', y='resale_price', data=bedok)
sb.lineplot(x='remaining_lease', y='resale_price', data=jw)
sb.lineplot(x='remaining_lease', y='resale_price', data=tampines)
sb.lineplot(x='remaining_lease', y='resale_price', data=woodlands)
sb.lineplot(x='remaining_lease', y='resale_price', data=yishun)
sb.lineplot(x='remaining_lease', y='resale_price', data=hougang)
sb.lineplot(x='remaining_lease', y='resale_price', data=bukitmerah)
sb.lineplot(x='remaining_lease', y='resale_price', data=amk)
sb.lineplot(x='remaining_lease', y='resale_price', data=toapayoh)
sb.lineplot(x='remaining_lease', y='resale_price', data=kallang)
sb.lineplot(x='remaining_lease', y='resale_price', data=bukitbatok)
sb.lineplot(x='remaining_lease', y='resale_price', data=geylang)
sb.lineplot(x='remaining_lease', y='resale_price', data=queenstown)
sb.lineplot(x='remaining_lease', y='resale_price', data=cck)
sb.lineplot(x='remaining_lease', y='resale_price', data=je)
sb.lineplot(x='remaining_lease', y='resale_price', data=clem)
sb.lineplot(x='remaining_lease', y='resale_price', data=bukitpanjang)
sb.lineplot(x='remaining_lease', y='resale_price', data=bishan)
sb.lineplot(x='remaining_lease', y='resale_price', data=serangoon)
sb.lineplot(x='remaining_lease', y='resale_price', data=sengkang)
sb.lineplot(x='remaining_lease', y='resale_price', data=pasirris)
sb.lineplot(x='remaining_lease', y='resale_price', data=marineparade)
sb.lineplot(x='remaining_lease', y='resale_price', data=sembawang)
sb.lineplot(x='remaining_lease', y='resale_price', data=punggol)
sb.lineplot(x='remaining_lease', y='resale_price', data=central)
sb.lineplot(x='remaining_lease', y='resale_price', data=bukittimah)
sb.lineplot(x='remaining_lease', y='resale_price', data=lck)
# Out:
# <AxesSubplot:xlabel='remaining_lease', ylabel='resale_price'>

# %%
room3 = room3.groupby("remaining_lease").median().reset_index()
room4 = room4.groupby("remaining_lease").median().reset_index()
room5 = room5.groupby("remaining_lease").median().reset_index()

# %%
f = plt.figure(figsize=(16, 8))
sb.lineplot(x='remaining_lease', y='resale_price', data=room3 , color = 'r')
sb.lineplot(x='remaining_lease', y='resale_price', data=room4 , color = 'b')
sb.lineplot(x='remaining_lease', y='resale_price', data=room5 , color = 'g')
# Out:
# <AxesSubplot:xlabel='remaining_lease', ylabel='resale_price'>

# %% [markdown]
# # 1990 - 1994

# %%
test31 = test3[(test3.year >= 1990) & (test3.year < 1995)]
test41 = test4[(test4.year >= 1990) & (test4.year < 1995)]
test51 = test5[(test5.year >= 1990) & (test5.year < 1995)]

# %%
univariateLinearRegression(Xvar = "remaining_lease", yvar = "resale_price", df = test31)
print("Correlation :")
test31.resale_price.corr(test31.remaining_lease)
# Out:
# Intercept 	: b =  [62051.38077159]
# Coefficients 	: a =  [[42.31028564]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 6.401207766859596e-05
# Mean Squared Error (MSE) 	: 857575855.1468594
#
# Prediction Accuracy of Model 	Test Dataset
# Mean Squared Error (MSE) 	: 943124141.6759408
#
# Correlation :
# 0.003198371862615016

# %%
univariateLinearRegression(Xvar = "remaining_lease", yvar = "resale_price", df = test41)
test41.resale_price.corr(test41.remaining_lease)
# Out:
# Intercept 	: b =  [212577.06109198]
# Coefficients 	: a =  [[-948.04465879]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.006626711003451358
# Mean Squared Error (MSE) 	: 2546623287.0103207
#
# Prediction Accuracy of Model 	Test Dataset
# Mean Squared Error (MSE) 	: 2534105845.9185114
# -0.08235180713709361

# %%
univariateLinearRegression(Xvar = "remaining_lease", yvar = "resale_price", df = test51)
test51.resale_price.corr(test51.remaining_lease)
# Out:
# Intercept 	: b =  [358991.57649358]
# Coefficients 	: a =  [[-1638.36828511]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.007681101563661308
# Mean Squared Error (MSE) 	: 5917890292.20041
#
# Prediction Accuracy of Model 	Test Dataset
# Mean Squared Error (MSE) 	: 5866917985.844102
# -0.09137016405332865

# %%
test31 = test31.groupby("remaining_lease").median().reset_index()
test41 = test41.groupby("remaining_lease").median().reset_index()
test51 = test51.groupby("remaining_lease").median().reset_index()
f = plt.figure(figsize=(16, 8))
sb.lineplot(x='remaining_lease', y='resale_price', data=test31 , color = 'r')
sb.lineplot(x='remaining_lease', y='resale_price', data=test41 , color = 'b')
sb.lineplot(x='remaining_lease', y='resale_price', data=test51 , color = 'g')
# Out:
# <AxesSubplot:xlabel='remaining_lease', ylabel='resale_price'>

# %% [markdown]
# For 3 Room, there is an slight increase in price at the end as the 3 room house that is being sold is a terrance which is slightly difference from a normal Flat
#
# For 4 Room, there is an increase in price as the 3 room house that is being sold is a terrance which is slightly difference from a normal Flat
#
# For 5 Room, it is just weird

# %% [markdown]
# # 1995 - 1999

# %%
test32 = test3[(test3.year >= 1995) & (test3.year < 2000)]
test42 = test4[(test4.year >= 1995) & (test4.year < 2000)]
test52 = test5[(test5.year >= 1995) & (test5.year < 2000)]

# %%
univariateLinearRegression(Xvar = "remaining_lease", yvar = "resale_price", df = test32)
test32.resale_price.corr(test32.remaining_lease)
# Out:
# Intercept 	: b =  [151924.46770771]
# Coefficients 	: a =  [[77.22063516]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.00011928656559567763
# Mean Squared Error (MSE) 	: 1685482773.1823723
#
# Prediction Accuracy of Model 	Test Dataset
# Mean Squared Error (MSE) 	: 1685969700.4973996
# 0.015008701455646483

# %%
univariateLinearRegression(Xvar = "remaining_lease", yvar = "resale_price", df = test42)
test42.resale_price.corr(test42.remaining_lease)
# Out:
# Intercept 	: b =  [145194.28260836]
# Coefficients 	: a =  [[1356.84149247]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.015677256407067852
# Mean Squared Error (MSE) 	: 3048004679.578244
#
# Prediction Accuracy of Model 	Test Dataset
# Mean Squared Error (MSE) 	: 3097993771.615076
# 0.1259583775209998

# %%
univariateLinearRegression(Xvar = "remaining_lease", yvar = "resale_price", df = test52)
test52.resale_price.corr(test52.remaining_lease)
# Out:
# Intercept 	: b =  [393529.33221385]
# Coefficients 	: a =  [[-60.23113625]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 2.1205198823759375e-05
# Mean Squared Error (MSE) 	: 5020318306.899158
#
# Prediction Accuracy of Model 	Test Dataset
# Mean Squared Error (MSE) 	: 5117387728.660859
# -0.006978510372480557

# %%
test32 = test32.groupby("remaining_lease").median().reset_index()
test42 = test42.groupby("remaining_lease").median().reset_index()
test52 = test52.groupby("remaining_lease").median().reset_index()
f = plt.figure(figsize=(16, 8))
sb.lineplot(x='remaining_lease', y='resale_price', data=test32 , color = 'r')
sb.lineplot(x='remaining_lease', y='resale_price', data=test42 , color = 'b')
sb.lineplot(x='remaining_lease', y='resale_price', data=test52 , color = 'g')
# Out:
# <AxesSubplot:xlabel='remaining_lease', ylabel='resale_price'>

# %% [markdown]
# For 3 Room, there is an slight increase in price at the end as the 3 room house that is being sold is a terrance which is slightly difference from a normal Flat
#
# For 4 Room, there is an increase in price as the 4 room house that is being sold is a terrance which is slightly difference from a normal Flat nad it causes the increase at the end

# %% [markdown]
# # 2000 - 2004

# %%
test33 = test3[(test3.year >= 2000) & (test3.year < 2005)]
test43 = test4[(test4.year >= 2000) & (test4.year < 2005)]
test53 = test5[(test5.year >= 2000) & (test5.year < 2005)]

# %%
univariateLinearRegression(Xvar = "remaining_lease", yvar = "resale_price", df = test33)
test33.resale_price.corr(test33.remaining_lease)
# Out:
# Intercept 	: b =  [166287.82514654]
# Coefficients 	: a =  [[-128.05660842]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.0004780951412093337
# Mean Squared Error (MSE) 	: 1225139508.5163298
#
# Prediction Accuracy of Model 	Test Dataset
# Mean Squared Error (MSE) 	: 1264914245.199853
# -0.021780007060690686

# %%
univariateLinearRegression(Xvar = "remaining_lease", yvar = "resale_price", df = test43)
test43.resale_price.corr(test43.remaining_lease)
# Out:
# Intercept 	: b =  [96380.07586289]
# Coefficients 	: a =  [[1676.64597594]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.06004424267568742
# Mean Squared Error (MSE) 	: 2183269253.9458256
#
# Prediction Accuracy of Model 	Test Dataset
# Mean Squared Error (MSE) 	: 2164881383.852818
# 0.24436396149064085

# %%
univariateLinearRegression(Xvar = "remaining_lease", yvar = "resale_price", df = test53)
test53.resale_price.corr(test53.remaining_lease)
# Out:
# Intercept 	: b =  [288701.68797885]
# Coefficients 	: a =  [[610.74668998]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.004678607830748582
# Mean Squared Error (MSE) 	: 4068251741.754975
#
# Prediction Accuracy of Model 	Test Dataset
# Mean Squared Error (MSE) 	: 4128547706.28642
# 0.06352012672680472

# %%
test33 = test33.groupby("remaining_lease").median().reset_index()
test43 = test43.groupby("remaining_lease").median().reset_index()
test53 = test53.groupby("remaining_lease").median().reset_index()
f = plt.figure(figsize=(16, 8))
sb.lineplot(x='remaining_lease', y='resale_price', data=test33 , color = 'r')
sb.lineplot(x='remaining_lease', y='resale_price', data=test43 , color = 'b')
sb.lineplot(x='remaining_lease', y='resale_price', data=test53 , color = 'g')
# Out:
# <AxesSubplot:xlabel='remaining_lease', ylabel='resale_price'>

# %% [markdown]
# For 4 Room, there is an increase in price as the 4 room house that is being sold is a terrance which is slightly difference from a normal Flat nad it causes the increase at the end

# %% [markdown]
# # 2005 - 2009

# %%
test34 = test3[(test3.year >= 2005) & (test3.year < 2009)]
test44 = test4[(test4.year >= 2005) & (test4.year < 2009)]
test54 = test5[(test5.year >= 2005) & (test5.year < 2009)]

# %%
univariateLinearRegression(Xvar = "remaining_lease", yvar = "resale_price", df = test34)
test34.resale_price.corr(test34.remaining_lease)
# Out:
# Intercept 	: b =  [268376.33084147]
# Coefficients 	: a =  [[-1109.42153594]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.023242228546173305
# Mean Squared Error (MSE) 	: 1966657628.4571579
#
# Prediction Accuracy of Model 	Test Dataset
# Mean Squared Error (MSE) 	: 1900195848.831624
# -0.153680995271464

# %%
univariateLinearRegression(Xvar = "remaining_lease", yvar = "resale_price", df = test44)
test44.resale_price.corr(test44.remaining_lease)
# Out:
# Intercept 	: b =  [168418.01556793]
# Coefficients 	: a =  [[1145.33139322]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.022466410896289202
# Mean Squared Error (MSE) 	: 4062297230.3973904
#
# Prediction Accuracy of Model 	Test Dataset
# Mean Squared Error (MSE) 	: 3973454152.0015397
# 0.14374018775330097

# %%
univariateLinearRegression(Xvar = "remaining_lease", yvar = "resale_price", df = test54)
test54.resale_price.corr(test54.remaining_lease)
# Out:
# Intercept 	: b =  [424729.97363958]
# Coefficients 	: a =  [[-976.075687]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.009254299579377179
# Mean Squared Error (MSE) 	: 6855029051.017973
#
# Prediction Accuracy of Model 	Test Dataset
# Mean Squared Error (MSE) 	: 6871299852.724929
# -0.09682882855206773

# %%
test34 = test34.groupby("remaining_lease").median().reset_index()
test44 = test44.groupby("remaining_lease").median().reset_index()
test54 = test54.groupby("remaining_lease").median().reset_index()
f = plt.figure(figsize=(16, 8))
sb.lineplot(x='remaining_lease', y='resale_price', data=test34 , color = 'r')
sb.lineplot(x='remaining_lease', y='resale_price', data=test44 , color = 'b')
sb.lineplot(x='remaining_lease', y='resale_price', data=test54 , color = 'g')
# Out:
# <AxesSubplot:xlabel='remaining_lease', ylabel='resale_price'>

# %% [markdown]
# For 4 room, the increase in median at the end is due to people again paying more for the terrance and Adjoined houses
#
# For 5 room, i supposed its location ?

# %% [markdown]
# # 2010 - 2014

# %%
test35 = test3[(test3.year >= 2010) & (test3.year < 2015)]
test45 = test4[(test4.year >= 2010) & (test4.year < 2015)]
test55 = test5[(test5.year >= 2010) & (test5.year < 2015)]

# %%
univariateLinearRegression(Xvar = "remaining_lease", yvar = "resale_price", df = test35)
test35.resale_price.corr(test35.remaining_lease)
# Out:
# Intercept 	: b =  [371380.34533562]
# Coefficients 	: a =  [[-596.4062451]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.004225699143576733
# Mean Squared Error (MSE) 	: 3810143962.887637
#
# Prediction Accuracy of Model 	Test Dataset
# Mean Squared Error (MSE) 	: 3887258588.6461024
# -0.06573141074384685

# %%
univariateLinearRegression(Xvar = "remaining_lease", yvar = "resale_price", df = test45)
test45.resale_price.corr(test45.remaining_lease)
# Out:
# Intercept 	: b =  [280898.57487869]
# Coefficients 	: a =  [[1920.34083724]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.038218013923040695
# Mean Squared Error (MSE) 	: 7653946540.198439
#
# Prediction Accuracy of Model 	Test Dataset
# Mean Squared Error (MSE) 	: 7659035464.065977
# 0.19400090367751704

# %%
univariateLinearRegression(Xvar = "remaining_lease", yvar = "resale_price", df = test55)
test55.resale_price.corr(test55.remaining_lease)
# Out:
# Intercept 	: b =  [703460.20034267]
# Coefficients 	: a =  [[-2274.74635604]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.031402276041766486
# Mean Squared Error (MSE) 	: 11678915755.495964
#
# Prediction Accuracy of Model 	Test Dataset
# Mean Squared Error (MSE) 	: 11569422631.379112
# -0.17689929220329212

# %%
test35 = test35.groupby("remaining_lease").median().reset_index()
test45 = test45.groupby("remaining_lease").median().reset_index()
test55 = test55.groupby("remaining_lease").median().reset_index()
f = plt.figure(figsize=(16, 8))
sb.lineplot(x='remaining_lease', y='resale_price', data=test35 , color = 'r')
sb.lineplot(x='remaining_lease', y='resale_price', data=test45 , color = 'b')
sb.lineplot(x='remaining_lease', y='resale_price', data=test55 , color = 'g')
# Out:
# <AxesSubplot:xlabel='remaining_lease', ylabel='resale_price'>

# %% [markdown]
# For 4 room , it is always the fucking terrance house
#
# For 5 room , the increase towards the end is due to poepl buy houses at good locations

# %% [markdown]
# # 2015 - 2020

# %%
test35 = test3[(test3.year >= 2015) & (test3.year < 2021)]
test45 = test4[(test4.year >= 2015) & (test4.year < 2021)]
test55 = test5[(test5.year >= 2015) & (test5.year < 2021)]

# %%
univariateLinearRegression(Xvar = "remaining_lease", yvar = "resale_price", df = test35)
test35.resale_price.corr(test35.remaining_lease)
# Out:
# Intercept 	: b =  [177984.85466402]
# Coefficients 	: a =  [[2156.12125041]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.11272652623954493
# Mean Squared Error (MSE) 	: 5106301792.24591
#
# Prediction Accuracy of Model 	Test Dataset
# Mean Squared Error (MSE) 	: 5379471437.756594
# 0.3384264761221147

# %%
univariateLinearRegression(Xvar = "remaining_lease", yvar = "resale_price", df = test45)
test45.resale_price.corr(test45.remaining_lease)
# Out:
# Intercept 	: b =  [179061.14279865]
# Coefficients 	: a =  [[3425.45158416]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.10333973135089936
# Mean Squared Error (MSE) 	: 13361645172.375982
#
# Prediction Accuracy of Model 	Test Dataset
# Mean Squared Error (MSE) 	: 13443270889.556625
# 0.3197559037556607

# %%
univariateLinearRegression(Xvar = "remaining_lease", yvar = "resale_price", df = test55)
test55.resale_price.corr(test55.remaining_lease)
# Out:
# Intercept 	: b =  [466643.19763854]
# Coefficients 	: a =  [[953.91539833]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.0040235845653795455
# Mean Squared Error (MSE) 	: 22510115576.275566
#
# Prediction Accuracy of Model 	Test Dataset
# Mean Squared Error (MSE) 	: 22608649833.900795
# 0.05940876725111544

# %%
test35 = test35.groupby("remaining_lease").median().reset_index()
test45 = test45.groupby("remaining_lease").median().reset_index()
test55 = test55.groupby("remaining_lease").median().reset_index()
f = plt.figure(figsize=(16, 8))
sb.lineplot(x='remaining_lease', y='resale_price', data=test35 , color = 'r')
sb.lineplot(x='remaining_lease', y='resale_price', data=test45 , color = 'b')
sb.lineplot(x='remaining_lease', y='resale_price', data=test55 , color = 'g')
# Out:
# <AxesSubplot:xlabel='remaining_lease', ylabel='resale_price'>

# %% [markdown]
# For 4 room, its due to adjoined flats and terrances again
