# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
hdb = pd.read_csv('./archive/hdb.csv')

# %%
hdb['date'] = pd.to_datetime(hdb['date'], format = '%Y-%m-%d')

# %%
hdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 826581 entries, 0 to 826580
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   date                 826581 non-null  datetime64[ns]
#  1   year                 826581 non-null  int64
#  2   month                826581 non-null  int64
#  3   town                 826581 non-null  object
#  4   flat_type            826581 non-null  object
#  5   block                826581 non-null  object
#  6   street_name          826581 non-null  object
#  7   storey_range         826581 non-null  object
#  8   floor_area_sqm       826581 non-null  float64
#  9   flat_model           826581 non-null  object
#  10  lease_commence_date  826581 non-null  int64
#  11  resale_price         826581 non-null  float64
#  12  remaining_lease      826581 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(6)
# memory usage: 82.0+ MB

# %%
hdb.head()
# Out:
#         date  year  month        town flat_type block        street_name  \
# 0 2015-01-01  2015      1  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4
# 1 2015-01-01  2015      1  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10
# 2 2015-01-01  2015      1  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4
# 3 2015-01-01  2015      1  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10
# 4 2015-01-01  2015      1  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10
#
#   storey_range  floor_area_sqm      flat_model  lease_commence_date  \
# 0     07 TO 09            60.0        Improved                 1986
# 1     01 TO 03            68.0  New Generation                 1981
# 2     01 TO 03            69.0  New Generation                 1980
# 3     01 TO 03            68.0  New Generation                 1979
# 4     07 TO 09            68.0  New Generation                 1980
#
#    resale_price  remaining_lease
# 0      255000.0               70
# 1      275000.0               65
# 2      285000.0               64
# 3      290000.0               63
# 4      290000.0               64

# %%
house = hdb.groupby(["town", "block", "flat_type", "street_name", "floor_area_sqm", "lease_commence_date"]).size().reset_index(name='counts').sort_values("counts", ascending = False)

# %%
house = house.reset_index(drop = True)

# %%
house
# Out:
#                   town block flat_type        street_name  floor_area_sqm  \
# 0          JURONG WEST   211    3 ROOM        BOON LAY PL            65.0
# 1          JURONG WEST   186    3 ROOM       BOON LAY AVE            59.0
# 2          JURONG WEST   185    3 ROOM       BOON LAY AVE            59.0
# 3          JURONG WEST   208    3 ROOM        BOON LAY PL            65.0
# 4          JURONG WEST   210    3 ROOM        BOON LAY PL            65.0
# ...                ...   ...       ...                ...             ...
# 36376      JURONG WEST   327    4 ROOM       TAH CHING RD           107.0
# 36377      JURONG WEST   326    5 ROOM       TAH CHING RD           119.0
# 36378      JURONG WEST   321    5 ROOM       TAH CHING RD           119.0
# 36379      JURONG WEST  272A    5 ROOM  JURONG WEST ST 24           115.0
# 36380  KALLANG/WHAMPOA     1    2 ROOM           BEACH RD            47.0
#
#        lease_commence_date  counts
# 0                     1976     667
# 1                     1975     618
# 2                     1975     615
# 3                     1976     613
# 4                     1977     612
# ...                    ...     ...
# 36376                 1997       1
# 36377                 1997       1
# 36378                 1997       1
# 36379                 2003       1
# 36380                 1979       1
#
# [36381 rows x 7 columns]

# %% [markdown]
# # Functions

# %%
def get_unit(unit):
    return  hdb[(hdb.town == unit.town) 
        & (hdb.block == unit.block) 
        & (hdb.flat_type == unit.flat_type) 
        & (hdb.street_name == unit.street_name) 
        & (hdb.floor_area_sqm == unit.floor_area_sqm)
        & (hdb.lease_commence_date == unit.lease_commence_date)]

# %%
def plot_unit_prices(num, house):
    for i in range(num):
        unit = house.iloc[i]
        a = get_unit(unit)
        a = a.loc[:,["date", "resale_price"]]
        a[f"{unit.flat_type} {unit.town}_{unit.block} ({unit.floor_area_sqm})"] = a["resale_price"]
        a.drop("resale_price", axis=1, inplace=True)
        a = a.reset_index(drop = True)
        if i == 0:
            master = a
        else:
            master = pd.concat([master, a], ignore_index=True)
    f = plt.figure(figsize=(16, 8))
    for i in range(len(master.columns)-1):
        ax = sb.lineplot(x = 'date', y = master.iloc[:, i+1], data = master)

#     ax.set_ylim(0,1000000)
    ax.set_xlim(pd.to_datetime("1990-01-01", format = '%Y-%m-%d'),pd.to_datetime("2020-01-01", format = '%Y-%m-%d'))
    ax.set(ylabel="resale_price")
    return master

# %%
def plot_median_unit_prices(num, house):
    for i in range(num):
        unit = house.iloc[i]
        a = get_unit(unit)
        a = a.loc[:,["date", "resale_price"]]
        if i == 0:
            master = a
        else:
            master = pd.concat([master, a], ignore_index=True)
    master = master.groupby("date").median().reset_index()
    f = plt.figure(figsize=(16, 8))
    sb.lineplot(x = 'date', y = "resale_price", data = master)
    return master

# %% [markdown]
# # Flat Type Breakdown

# %%
flat_type_breakdown = hdb.groupby("flat_type").size().reset_index(name = "counts").sort_values("counts", ascending = False)

# %%
flat_type_breakdown
# Out:
#           flat_type  counts
# 3            4 ROOM  309314
# 2            3 ROOM  272580
# 4            5 ROOM  170408
# 5         EXECUTIVE   62641
# 1            2 ROOM    9863
# 0            1 ROOM    1273
# 6  MULTI GENERATION     279
# 7  MULTI-GENERATION     223

# %%
sb.catplot(y = "flat_type", data = hdb, order = hdb['flat_type'].value_counts().index, kind = "count", height=5, aspect=5)

# %% [markdown]
# # 3 ROOM Resale Price vs Time

# %%
rm3_house = house[(house.flat_type == "3 ROOM")]

# %%
f = plt.figure(figsize=(16, 8))
sb.histplot(data = rm3_house.loc[:,["counts"]])
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
rm3_house
# Out:
#               town block flat_type    street_name  floor_area_sqm  \
# 0      JURONG WEST   211    3 ROOM    BOON LAY PL            65.0
# 1      JURONG WEST   186    3 ROOM   BOON LAY AVE            59.0
# 2      JURONG WEST   185    3 ROOM   BOON LAY AVE            59.0
# 3      JURONG WEST   208    3 ROOM    BOON LAY PL            65.0
# 4      JURONG WEST   210    3 ROOM    BOON LAY PL            65.0
# ...            ...   ...       ...            ...             ...
# 36342  JURONG WEST   172    3 ROOM    BOON LAY DR            64.0
# 36343  JURONG WEST   171    3 ROOM    BOON LAY DR            64.0
# 36344  JURONG WEST   170    3 ROOM    BOON LAY DR            64.0
# 36369  JURONG WEST  339C    3 ROOM  KANG CHING RD            70.0
# 36370  JURONG WEST  338B    3 ROOM  KANG CHING RD            70.0
#
#        lease_commence_date  counts
# 0                     1976     667
# 1                     1975     618
# 2                     1975     615
# 3                     1976     613
# 4                     1977     612
# ...                    ...     ...
# 36342                 1974       1
# 36343                 1974       1
# 36344                 1974       1
# 36369                 2012       1
# 36370                 2012       1
#
# [5869 rows x 7 columns]

# %%
rm3 = plot_unit_prices(500, rm3_house)

# %%
rm3 = plot_unit_prices(500, rm3_house)

# %% [markdown]
# # 4 ROOM Resale Price vs Time

# %%
rm4_house = house[(house.flat_type == "4 ROOM") & (house.counts > 80)]

# %%
f = plt.figure(figsize=(16, 8))
sb.histplot(data = rm4_house.loc[:,["counts"]])
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
rm4_house
# Out:
#              town block flat_type         street_name  floor_area_sqm  \
# 64          BEDOK    34    4 ROOM     BEDOK STH AVE 2            90.0
# 70    JURONG WEST   217    4 ROOM        BOON LAY AVE            87.0
# 74     QUEENSTOWN  168A    4 ROOM           QUEENSWAY            84.0
# 78      TOA PAYOH   222    4 ROOM     LOR 8 TOA PAYOH            82.0
# 81       CLEMENTI   716    4 ROOM  CLEMENTI WEST ST 2            91.0
# ...           ...   ...       ...                 ...             ...
# 2176    SERANGOON   328    4 ROOM     SERANGOON AVE 3            84.0
# 2177       YISHUN   805    4 ROOM      YISHUN RING RD            84.0
# 2180   ANG MO KIO   544    4 ROOM   ANG MO KIO AVE 10            92.0
# 2182       YISHUN   257    4 ROOM      YISHUN RING RD            84.0
# 2187    SERANGOON   307    4 ROOM     SERANGOON AVE 2            95.0
#
#       lease_commence_date  counts
# 64                   1977     242
# 70                   1975     238
# 74                   1974     237
# 78                   1976     235
# 81                   1981     235
# ...                   ...     ...
# 2176                 1986      81
# 2177                 1987      81
# 2180                 1981      81
# 2182                 1986      81
# 2187                 1985      81
#
# [542 rows x 7 columns]

# %%
rm4 = plot_unit_prices(500, rm4_house)

# %%
rm4
# Out:
#             date  4 ROOM BEDOK_34 (90.0)  4 ROOM JURONG WEST_217 (87.0)  \
# 0     2015-01-01                405000.0                            NaN
# 1     2015-05-01                410000.0                            NaN
# 2     2015-06-01                417000.0                            NaN
# 3     2016-01-01                410000.0                            NaN
# 4     2016-03-01                406000.0                            NaN
# ...          ...                     ...                            ...
# 55845 2011-04-01                     NaN                            NaN
# 55846 2011-09-01                     NaN                            NaN
# 55847 2012-02-01                     NaN                            NaN
# 55848 2013-11-01                     NaN                            NaN
# 55849 2014-12-01                     NaN                            NaN
#
#        4 ROOM QUEENSTOWN_168A (84.0)  4 ROOM TOA PAYOH_222 (82.0)  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
# ...                              ...                          ...
# 55845                            NaN                          NaN
# 55846                            NaN                          NaN
# 55847                            NaN                          NaN
# 55848                            NaN                          NaN
# 55849                            NaN                          NaN
#
#        4 ROOM CLEMENTI_716 (91.0)  4 ROOM BEDOK_36 (84.0)  \
# 0                             NaN                     NaN
# 1                             NaN                     NaN
# 2                             NaN                     NaN
# 3                             NaN                     NaN
# 4                             NaN                     NaN
# ...                           ...                     ...
# 55845                         NaN                     NaN
# 55846                         NaN                     NaN
# 55847                         NaN                     NaN
# 55848                         NaN                     NaN
# 55849                         NaN                     NaN
#
#        4 ROOM BEDOK_51 (84.0)  4 ROOM BEDOK_718 (104.0)  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# ...                       ...                       ...
# 55845                     NaN                       NaN
# 55846                     NaN                       NaN
# 55847                     NaN                       NaN
# 55848                     NaN                       NaN
# 55849                     NaN                       NaN
#
#        4 ROOM BEDOK_35 (90.0)  ...  4 ROOM YISHUN_174 (84.0)  \
# 0                         NaN  ...                       NaN
# 1                         NaN  ...                       NaN
# 2                         NaN  ...                       NaN
# 3                         NaN  ...                       NaN
# 4                         NaN  ...                       NaN
# ...                       ...  ...                       ...
# 55845                     NaN  ...                       NaN
# 55846                     NaN  ...                       NaN
# 55847                     NaN  ...                       NaN
# 55848                     NaN  ...                       NaN
# 55849                     NaN  ...                       NaN
#
#        4 ROOM TAMPINES_856 (84.0)  4 ROOM CLEMENTI_324 (91.0)  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ...                           ...                         ...
# 55845                         NaN                         NaN
# 55846                         NaN                         NaN
# 55847                         NaN                         NaN
# 55848                         NaN                         NaN
# 55849                         NaN                         NaN
#
#        4 ROOM GEYLANG_320 (84.0)  4 ROOM SERANGOON_332 (84.0)  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# ...                          ...                          ...
# 55845                        NaN                          NaN
# 55846                        NaN                          NaN
# 55847                        NaN                          NaN
# 55848                        NaN                          NaN
# 55849                        NaN                          NaN
#
#        4 ROOM BUKIT BATOK_363 (94.0)  4 ROOM PASIR RIS_633 (104.0)  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
# ...                              ...                           ...
# 55845                            NaN                           NaN
# 55846                            NaN                           NaN
# 55847                            NaN                           NaN
# 55848                            NaN                           NaN
# 55849                            NaN                           NaN
#
#        4 ROOM WOODLANDS_786D (100.0)  4 ROOM CHOA CHU KANG_285 (104.0)  \
# 0                                NaN                               NaN
# 1                                NaN                               NaN
# 2                                NaN                               NaN
# 3                                NaN                               NaN
# 4                                NaN                               NaN
# ...                              ...                               ...
# 55845                            NaN                               NaN
# 55846                            NaN                               NaN
# 55847                            NaN                               NaN
# 55848                            NaN                               NaN
# 55849                            NaN                               NaN
#
#        4 ROOM BUKIT MERAH_113 (103.0)
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 55845                        510000.0
# 55846                        545000.0
# 55847                        560000.0
# 55848                        586800.0
# 55849                        580000.0
#
# [55850 rows x 501 columns]

# %% [markdown]
# # 5 ROOM Resale Price vs Time

# %%
rm5_house = house[(house.flat_type == "5 ROOM") & (house.counts > 55)]

# %%
f = plt.figure(figsize=(16, 8))
sb.histplot(data = rm5_house.loc[:,["counts"]])
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
rm5_house.shape
# Out:
# (517, 7)

# %%
rm5 = plot_unit_prices(500, rm5_house)

# %%
rm5_median = plot_median_unit_prices(190, rm5_house)

# %%
rm5_median
# Out:
#           date  resale_price
# 0   1990-01-01      129000.0
# 1   1990-02-01      126750.0
# 2   1990-03-01      110000.0
# 3   1990-04-01      127000.0
# 4   1990-05-01      139750.0
# ..         ...           ...
# 364 2020-05-01      540000.0
# 365 2020-06-01      500000.0
# 366 2020-07-01      475000.0
# 367 2020-08-01      509000.0
# 368 2020-09-01      507500.0
#
# [369 rows x 2 columns]

# %% [markdown]
# # 3-5 Room Median

# %%
hdb
# Out:
#              date  year  month        town  flat_type block  \
# 0      2015-01-01  2015      1  ANG MO KIO     3 ROOM   174
# 1      2015-01-01  2015      1  ANG MO KIO     3 ROOM   541
# 2      2015-01-01  2015      1  ANG MO KIO     3 ROOM   163
# 3      2015-01-01  2015      1  ANG MO KIO     3 ROOM   446
# 4      2015-01-01  2015      1  ANG MO KIO     3 ROOM   557
# ...           ...   ...    ...         ...        ...   ...
# 826576 2014-12-01  2014     12      YISHUN     5 ROOM   816
# 826577 2014-12-01  2014     12      YISHUN  EXECUTIVE   325
# 826578 2014-12-01  2014     12      YISHUN  EXECUTIVE   618
# 826579 2014-12-01  2014     12      YISHUN  EXECUTIVE   277
# 826580 2014-12-01  2014     12      YISHUN  EXECUTIVE   277
#
#               street_name storey_range  floor_area_sqm      flat_model  \
# 0        ANG MO KIO AVE 4     07 TO 09            60.0        Improved
# 1       ANG MO KIO AVE 10     01 TO 03            68.0  New Generation
# 2        ANG MO KIO AVE 4     01 TO 03            69.0  New Generation
# 3       ANG MO KIO AVE 10     01 TO 03            68.0  New Generation
# 4       ANG MO KIO AVE 10     07 TO 09            68.0  New Generation
# ...                   ...          ...             ...             ...
# 826576       YISHUN ST 81     10 TO 12           122.0        Improved
# 826577        YISHUN CTRL     10 TO 12           146.0      Maisonette
# 826578     YISHUN RING RD     07 TO 09           164.0       Apartment
# 826579       YISHUN ST 22     07 TO 09           152.0      Maisonette
# 826580       YISHUN ST 22     04 TO 06           146.0      Maisonette
#
#         lease_commence_date  resale_price  remaining_lease
# 0                      1986      255000.0               70
# 1                      1981      275000.0               65
# 2                      1980      285000.0               64
# 3                      1979      290000.0               63
# 4                      1980      290000.0               64
# ...                     ...           ...              ...
# 826576                 1988      580000.0               73
# 826577                 1988      540000.0               73
# 826578                 1992      738000.0               77
# 826579                 1985      592000.0               70
# 826580                 1985      545000.0               70
#
# [826581 rows x 13 columns]

# %%
hdb_35 = hdb[(hdb.flat_type == "3 ROOM") | (hdb.flat_type == "4 ROOM") | (hdb.flat_type == "5 ROOM")]

# %%
hdb_35
# Out:
#              date  year  month        town flat_type block        street_name  \
# 0      2015-01-01  2015      1  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4
# 1      2015-01-01  2015      1  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10
# 2      2015-01-01  2015      1  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4
# 3      2015-01-01  2015      1  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10
# 4      2015-01-01  2015      1  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10
# ...           ...   ...    ...         ...       ...   ...                ...
# 826572 2014-12-01  2014     12      YISHUN    5 ROOM   612       YISHUN ST 61
# 826573 2014-12-01  2014     12      YISHUN    5 ROOM   713       YISHUN ST 71
# 826574 2014-12-01  2014     12      YISHUN    5 ROOM   757       YISHUN ST 72
# 826575 2014-12-01  2014     12      YISHUN    5 ROOM   819       YISHUN ST 81
# 826576 2014-12-01  2014     12      YISHUN    5 ROOM   816       YISHUN ST 81
#
#        storey_range  floor_area_sqm      flat_model  lease_commence_date  \
# 0          07 TO 09            60.0        Improved                 1986
# 1          01 TO 03            68.0  New Generation                 1981
# 2          01 TO 03            69.0  New Generation                 1980
# 3          01 TO 03            68.0  New Generation                 1979
# 4          07 TO 09            68.0  New Generation                 1980
# ...             ...             ...             ...                  ...
# 826572     04 TO 06           121.0        Improved                 1987
# 826573     01 TO 03           122.0        Improved                 1987
# 826574     01 TO 03           122.0        Improved                 1986
# 826575     01 TO 03           127.0        Improved                 1987
# 826576     10 TO 12           122.0        Improved                 1988
#
#         resale_price  remaining_lease
# 0           255000.0               70
# 1           275000.0               65
# 2           285000.0               64
# 3           290000.0               63
# 4           290000.0               64
# ...              ...              ...
# 826572      445000.0               72
# 826573      415000.0               72
# 826574      485000.0               71
# 826575      500000.0               72
# 826576      580000.0               73
#
# [752302 rows x 13 columns]

# %%
a = hdb_35[hdb_35.flat_type == "3 ROOM"].groupby(["date"]).median().reset_index()

# %%
a["resale_price"]
# Out:
# 0       42000.0
# 1       45000.0
# 2       43000.0
# 3       44000.0
# 4       43000.0
#          ...
# 364    282000.0
# 365    285000.0
# 366    285000.0
# 367    293000.0
# 368    295044.0
# Name: resale_price, Length: 369, dtype: float64

# %%
hdb_median_35 = None
for i in range(3, 5+1):
    a = hdb_35[hdb_35.flat_type == f"{i} ROOM"].groupby(["date"]).median().reset_index()
    if hdb_median_35 is None:
        hdb_median_35 = pd.DataFrame({"date": a["date"], f"{i} ROOM": a["resale_price"]})
        print(hdb_median_35.head(5))
    else:
        b = pd.DataFrame({"date": a["date"], f"{i} ROOM": a["resale_price"]})
        hdb_median_35 = pd.concat([hdb_median_35, b], ignore_index=True)
# Out:
#         date   3 ROOM
# 0 1990-01-01  42000.0
# 1 1990-02-01  45000.0
# 2 1990-03-01  43000.0
# 3 1990-04-01  44000.0
# 4 1990-05-01  43000.0

# %%
hdb_median_35
# Out:
#            date   3 ROOM  4 ROOM    5 ROOM
# 0    1990-01-01  42000.0     NaN       NaN
# 1    1990-02-01  45000.0     NaN       NaN
# 2    1990-03-01  43000.0     NaN       NaN
# 3    1990-04-01  44000.0     NaN       NaN
# 4    1990-05-01  43000.0     NaN       NaN
# ...         ...      ...     ...       ...
# 1102 2020-05-01      NaN     NaN  505000.0
# 1103 2020-06-01      NaN     NaN  488000.0
# 1104 2020-07-01      NaN     NaN  508000.0
# 1105 2020-08-01      NaN     NaN  490000.0
# 1106 2020-09-01      NaN     NaN  509500.0
#
# [1107 rows x 4 columns]

# %%
f = plt.figure(figsize=(16, 8))
ax = sb.lineplot(x = 'date', y = "3 ROOM", data = hdb_median_35, label="3 ROOM")
ax = sb.lineplot(x = 'date', y = "4 ROOM", data = hdb_median_35, label="4 ROOM")
ax = sb.lineplot(x = 'date', y = "5 ROOM", data = hdb_median_35, label="5 ROOM")
ax.set(ylabel="resale_price")
# Out:
# [Text(0, 0.5, 'resale_price')]

# %%
f = plt.figure(figsize=(16, 8))
ax = sb.lineplot(x = 'date', y = "3 ROOM", data = hdb_median_35, label="3 ROOM")

# %%
f = plt.figure(figsize=(16, 8))
ax = sb.lineplot(x = 'date', y = "4 ROOM", data = hdb_median_35, label="4 ROOM")

# %%
f = plt.figure(figsize=(16, 8))
ax = sb.lineplot(x = 'date', y = "5 ROOM", data = hdb_median_35, label="5 ROOM")

# %% [markdown]
# # Testing Playground

# %%
f = plt.figure(figsize=(16, 8))
sb.lineplot(x = 'date', y = "resale_price", data = rm5_geylang_median).set_ylim(0, 1000000)
sb.lineplot(x = 'date', y = "geylang", data = rm5_geylang_median)
# Out:
# <AxesSubplot:xlabel='date', ylabel='resale_price'>

# %%
test = rm5_house[(rm5_house.town == "GEYLANG") & (rm5_house.block == "60")]

# %%
test
# Out:
#           town block flat_type  street_name  floor_area_sqm  \
# 12061  GEYLANG    60    5 ROOM  DAKOTA CRES           140.0
#
#        lease_commence_date  counts
# 12061                 1983     108

# %%
rm5_median = rm5.groupby("date").median().reset_index()

# %%
rm5["5 ROOM GEYLANG_60 (140.0)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 18961   NaN
# 18962   NaN
# 18963   NaN
# 18964   NaN
# 18965   NaN
# Name: 5 ROOM GEYLANG_60 (140.0), Length: 18966, dtype: float64

# %%
rm5_geylang = pd.DataFrame({"date": rm5["date"], "geylang": rm5["5 ROOM GEYLANG_60 (140.0)"]})

# %%
rm5_geylang_median = pd.concat([rm5_median, rm5_geylang], ignore_index=True)

# %%
rm5_geylang_median
# Out:
#             date  resale_price  geylang
# 0     1990-01-01      129000.0      NaN
# 1     1990-02-01      126750.0      NaN
# 2     1990-03-01      110000.0      NaN
# 3     1990-04-01      127000.0      NaN
# 4     1990-05-01      139750.0      NaN
# ...          ...           ...      ...
# 19330 2011-11-01           NaN      NaN
# 19331 2012-02-01           NaN      NaN
# 19332 2012-03-01           NaN      NaN
# 19333 2013-04-01           NaN      NaN
# 19334 2013-10-01           NaN      NaN
#
# [19335 rows x 3 columns]

# %%
test.loc[12061, "flat_type"] = "4 ROOM"
# Out:
# /Users/bryan/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
test
# Out:
#           town block flat_type  street_name  floor_area_sqm  \
# 12061  GEYLANG    60    4 ROOM  DAKOTA CRES           140.0
#
#        lease_commence_date  counts
# 12061                 1983     108

# %%
test
# Out:
#           town block flat_type  street_name  floor_area_sqm  \
# 12061  GEYLANG    60    3 ROOM  DAKOTA CRES           140.0
#
#        lease_commence_date  counts
# 12061                 1983     108

# %%
rm5 = plot_unit_prices(1, test)
